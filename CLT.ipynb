# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# takw some random data and obs distribuation
data=np.random.randint(1,1000,10000)

# I want select 10000 observations/data points
# the values between 1 to 1000
# no value less than 1 and greater than 1000
len(data)
# Out:
# 10000

# %%
data
# Out:
# array([448, 244, 640, ..., 168, 416, 412])

# %%
#plot histogram
plt.hist(data,bins=500)
plt.show()

# %%
sns.distplot(data)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22924\2883516215.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data)

# %% [markdown]
# $Step-4$:
#
# - Select 100 samples from 10000 observations
# - Each sample has 100 observations

# %%
data # 10000

10000/100
# Out:
# 100.0

# %%
mean_list=[]
for i in range(100):
    s=np.random.randint(1,1000,100)
    mean_list.append(np.mean(s))

# %%
mean_list
# Out:
# [537.84,
#  526.07,
#  538.07,
#  497.8,
#  486.15,
#  522.64,
#  488.61,
#  483.28,
#  511.91,
#  516.28,
#  532.87,
#  494.85,
#  489.61,
#  472.68,
#  523.74,
#  524.96,
#  502.98,
#  490.58,
#  489.49,
#  507.98,
#  433.47,
#  523.22,
#  454.47,
#  482.55,
#  453.85,
#  537.65,
#  523.4,
#  504.17,
#  478.83,
#  538.76,
#  511.76,
#  522.86,
#  474.02,
#  526.34,
#  446.52,
#  479.02,
#  528.89,
#  496.92,
#  525.97,
#  474.74,
#  472.57,
#  512.84,
#  487.3,
#  507.2,
#  488.77,
#  475.72,
#  471.32,
#  488.15,
#  506.94,
#  508.64,
#  535.11,
#  476.74,
#  476.28,
#  516.95,
#  483.99,
#  451.48,
#  479.44,
#  460.6,
#  455.53,
#  496.84,
#  471.27,
#  493.56,
#  497.21,
#  485.33,
#  489.49,
#  464.42,
#  488.85,
#  498.15,
#  495.93,
#  479.11,
#  455.93,
#  497.27,
#  487.11,
#  533.72,
#  496.32,
#  544.19,
#  462.44,
#  503.22,
#  501.63,
#  504.61,
#  520.31,
#  439.59,
#  494.06,
#  501.12,
#  477.17,
#  547.79,
#  454.0,
#  494.54,
#  482.55,
#  521.91,
#  551.97,
#  505.66,
#  559.24,
#  528.29,
#  481.12,
#  506.14,
#  515.18,
#  523.73,
#  483.87,
#  497.9]

# %%
plt.hist(mean_list)
plt.show()

# %%
mean_list2=[]
for i in range(200):
    s=np.random.randint(1,1000,200)
    mean_list2.append(np.mean(s))

# %%
plt.hist(mean_list2)
plt.show()

# %% [markdown]
# - First we took 10000 observations values vaeries 1 to 1000
#
# - We plot histogram
#
# - The plot does not follows normal distribution
#
# - we took 100 samples each sample size also 100, values varies from 1 to 1000
#
# - we calculate mean of 100 samples : 100 means
#
# - we plot histogram of 100 means
#
# - then it follows normal distribution

# %% [markdown]
# # Method-2:
#
# - In the above one we directly took 100 samples randomly
#
# - No will take 100 samples randomly from a avialable data having 1000 observations

# %%
import random
data=np.random.randint(1,1000,10000)

mean_s=[]
for i in range(100):
    s=random.sample(sorted(data),100)
    mean=np.me5an(s)
    mean_s.append(mean)

# %%
plt.hist(mean_s)
# Out:
# (array([ 4.,  3.,  7., 14., 20., 15., 17., 11.,  6.,  3.]),
#  array([444.61, 456.26, 467.91, 479.56, 491.21, 502.86, 514.51, 526.16,
#         537.81, 549.46, 561.11]),
#  <BarContainer object of 10 artists>)
